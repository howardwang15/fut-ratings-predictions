# %%
import requests

data = []
for i in range(1, 5):
    response = requests.get('https://www.easports.com/fifa/ultimate-team/api/fut/item?page={}'.format(i))
    json = response.json()
    data.append(json)

items = [item['items'] for item in data]
items = [item for sublist in items for item in sublist]

# %%
keys = ['attributes', 'rating']
players = []
for item in items:
    player = dict()
    if not item['commonName']:
        player.update({'name': item['firstName'] + ' ' + item['lastName']})
    else:
        player.update({'name': item['commonName']})
    for key in keys:
        player.update({key: item[key]})
    for attribute in item['attributes']:
        print(attribute['name'])
    players.append(player)
            
# print(players)
# Out:
# [{'name': 'Pelé', 'attributes': [{'name': 'fut.attribute.PAC', 'value': 95, 'chemistryBonus': [0]}, {'name': 'fut.attribute.SHO', 'value': 96, 'chemistryBonus': [0]}, {'name': 'fut.attribute.PAS', 'value': 93, 'chemistryBonus': [0]}, {'name': 'fut.attribute.DRI', 'value': 96, 'chemistryBonus': [0]}, {'name': 'fut.attribute.DEF', 'value': 60, 'chemistryBonus': [0]}, {'name': 'fut.attribute.PHY', 'value': 76, 'chemistryBonus': [0]}], 'rating': 98}, {'name': 'Diego Maradona', 'attributes': [{'name': 'fut.attribute.PAC', 'value': 92, 'chemistryBonus': [0]}, {'name': 'fut.attribute.SHO', 'value': 93, 'chemistryBonus': [0]}, {'name': 'fut.attribute.PAS', 'value': 92, 'chemistryBonus': [0]}, {'name': 'fut.attribute.DRI', 'value': 97, 'chemistryBonus': [0]}, {'name': 'fut.attribute.DEF', 'value': 40, 'chemistryBonus': [0]}, {'name': 'fut.attribute.PHY', 'value': 76, 'chemistryBonus': [0]}], 'rating': 97}, {'name': 'Ronaldo', 'attributes': [{'name': 'fut.attribute.PAC', 'value': 97, 'chemistryBonus': [0]}, {'name': 'fut.attribute.SHO', 'value': 95, 'chemistryBonus': [0]}, {'name': 'fut.attribute.PAS', 'value': 81, 'chemistryBonus': [0]}, {'name': 'fut.attribute.DRI', 'value': 95, 'chemistryBonus': [0]}, {'name': 'fut.attribute.DEF', 'value': 45, 'chemistryBonus': [0]}, {'name': 'fut.attribute.PHY', 'value': 76, 'chemistryBonus': [0]}], 'rating': 96}, {'name': 'Pelé', 'attributes': [{'name': 'fut.attribute.PAC', 'value': 96, 'chemistryBonus': [0]}, {'name': 'fut.attribute.SHO', 'value': 93, 'chemistryBonus': [0]}, {'name': 'fut.attribute.PAS', 'value': 90, 'chemistryBonus': [0]}, {'name': 'fut.attribute.DRI', 'value': 95, 'chemistryBonus': [0]}, {'name': 'fut.attribute.DEF', 'value': 56, 'chemistryBonus': [0]}, {'name': 'fut.attribute.PHY', 'value': 75, 'chemistryBonus': [0]}], 'rating': 95}, {'name': 'Diego Maradona', 'attributes': [{'name': 'fut.attribute.PAC', 'value': 88, 'chemistryBonus': [0]}, {'name': 'fut.attribute.SHO', 'value': 91, 'chemistryBonus': [0]}, {'name': 'fut.attribute.PAS', 'value': 90, 'chemistryBonus': [0]}, {'name': 'fut.attribute.DRI', 'value': 95, 'chemistryBonus': [0]}, {'name': 'fut.attribute.DEF', 'value': 42, 'chemistryBonus': [0]}, {'name': 'fut.attribute.PHY', 'value': 75, 'chemistryBonus': [0]}], 'rating': 95}, {'name': 'Lionel Messi', 'attributes': [{'name': 'fut.attribute.PAC', 'value': 89, 'chemistryBonus': [0]}, {'name': 'fut.attribute.SHO', 'value': 92, 'chemistryBonus': [0]}, {'name': 'fut.attribute.PAS', 'value': 89, 'chemistryBonus': [0]}, {'name': 'fut.attribute.DRI', 'value': 97, 'chemistryBonus': [0]}, {'name': 'fut.attribute.DEF', 'value': 33, 'chemistryBonus': [0]}, {'name': 'fut.attribute.PHY', 'value': 62, 'chemistryBonus': [0]}], 'rating': 95}, {'name': 'Cristiano Ronaldo', 'attributes': [{'name': 'fut.attribute.PAC', 'value': 91, 'chemistryBonus': [0]}, {'name': 'fut.attribute.SHO', 'value': 94, 'chemistryBonus': [0]}, {'name': 'fut.attribute.PAS', 'value': 82, 'chemistryBonus': [0]}, {'name': 'fut.attribute.DRI', 'value': 91, 'chemistryBonus': [0]}, {'name': 'fut.attribute.DEF', 'value': 36, 'chemistryBonus': [0]}, {'name': 'fut.attribute.PHY', 'value': 80, 'chemistryBonus': [0]}], 'rating': 95}, {'name': 'Lionel Messi', 'attributes': [{'name': 'fut.attribute.PAC', 'value': 89, 'chemistryBonus': [0]}, {'name': 'fut.attribute.SHO', 'value': 92, 'chemistryBonus': [0]}, {'name': 'fut.attribute.PAS', 'value': 90, 'chemistryBonus': [0]}, {'name': 'fut.attribute.DRI', 'value': 97, 'chemistryBonus': [0]}, {'name': 'fut.attribute.DEF', 'value': 33, 'chemistryBonus': [0]}, {'name': 'fut.attribute.PHY', 'value': 64, 'chemistryBonus': [0]}], 'rating': 95}, {'name': 'Cristiano Ronaldo', 'attributes': [{'name': 'fut.attribute.PAC', 'value': 90, 'chemistryBonus': [0]}, {'name': 'fut.attribute.SHO', 'value': 93, 'chemistryBonus': [0]}, {'name': 'fut.attribute.PAS', 'value': 81, 'chemistryBonus': [0]}, {'name': 'fut.attribute.DRI', 'value': 90, 'chemistryBonus': [0]}, {'name': 'fut.attribute.DEF', 'val ...
